# %%
#################################Module For Functional Programing#############################################
from functools import reduce
from itertools import chain
from itertools import groupby
curry = lambda f: lambda a,*args: f(a, *args) if (len(args)) else lambda *args: f(a, *args)

filter = curry(filter)
map = curry(map)
reduce = curry(reduce)

go = lambda *args: reduce(lambda a,f: f(a), args) ## 함수도 축약 가능 ##

def dictUpdate(dic1,dic2):
    res = {**dic1,**dic2}
    return res
    
def dictsMerge(dics):
    res = reduce(dictUpdate, dics)
    return res
    
def dictDeleteKeys(dic, keys):
    for k in keys:
        del dic[k]
    return dic
##############################################################################################################

# %%
from itertools import groupby

# %%
# tgt = [
#     {"b":[2]},
#     {"a":[0]},
#     {"c":[3]},    
#     {"a":[1]},
# ]

tgt = [
    {
        "c":{
            "wmSpecs": [2]
        }
    },
    {
        "a":{
            "wmSpecs": [0]
        }
    },
    {
        "d":{
            "wmSpecs": [3]
        }
    },
    {
        "a":{
            "wmSpecs": [1]
        }
    },
]

# %%
def addi(a,b):
    return a+b

# %%
addi(b=7,a=3)
# Out:
# 10

# %%
def dictsUnion_(dicts, searchKey, foldTargetKeys, newKeyName):
    """
    키 구성이 동일한 다수 딕셔너리 중, 특정 키의 값이 동일한 것들만 골라서
    동일한 그룹 중 첫째 딕셔너리를 기준으로 특정 키들의 값을 묶은 뒤
    """
    pass

# %%
def dictsUnion_withInnerKey(dicts:list,innerkey):
    """
    최상위 키값이 "하나"인 복수의 딕셔너리 중 , 키 값이 동일한 것이 있을 때 딕셔너리별로 해당 키에 대응하는 값들을
    맨 처음의 딕셔너리로 값으로 재할당하고 해당 딕셔너리만 반환
    """
    # 최상위 키값을 기준으로 딕셔너리들 그루핑
    groupedDicts = go(
        dicts,
        lambda col: sorted(col, key=lambda x:list(x.keys())),
        lambda col: groupby(col, lambda x: list(x.keys())),
        map(lambda x: list(map(lambda y: list(y), x))),
        list,
    )
    # 최상위 키값이 중복되는 딕셔너리를 모은 리스트
    plurals = list(map(lambda y: y[1], filter(lambda x: len(x[1])>1, groupedDicts)))
    # 최상위 키값이 다른 어떤 딕셔너리와 중복되지 않는 단일 개체들 모은 리스트
    singles = list(map(lambda y: y[1][0], filter(lambda x: len(x[1])==1, groupedDicts)))
    
    
    ## plurals 없는 경우 처리
    if len(plurals)==0:
        res = singles
    else:
        sameKeyGroup = plurals[0]
        for sameKeyGroup in plurals:
            keys = list(sameKeyGroup[0].keys())
            newD = {keys[0]: {innerkey: []}}
            for d in sameKeyGroup:
                newD[keys[0]][innerkey].append(d[keys[0]][innerkey])
        res = [newD]+singles
    return res
   
   
dictsUnion_withInnerKey(tgt,"wmSpecs")
# Out:
# [{'a': {'wmSpecs': [[0], [1]]}},
#  {'c': {'wmSpecs': [2]}},
#  {'d': {'wmSpecs': [3]}}]

# %%
tgt2 = [
    {
        "c":{
            "wmSpecs": [2]
        }
    },
    {
        "a":{
            "wmSpecs": [0]
        }
    },
    {
        "d":{
            "wmSpecs": [3]
        }
    },
    {
        "b":{
            "wmSpecs": [1]
        }
    },
]

# %%
dictsUnion_withInnerKey(tgt2,"wmSpecs")
# Out:
# [{'a': {'wmSpecs': [0]}},
#  {'b': {'wmSpecs': [1]}},
#  {'c': {'wmSpecs': [2]}},
#  {'d': {'wmSpecs': [3]}}]

# %% [markdown]
# ## import jsonTxt

# %%
import json

# %%
with open("dict_extract.txt", "r",encoding='UTF-8') as f:
    jsonDB = f.read()

# %%
importedDB = json.loads(jsonDB)
print(importedDB)
# Out:
# [{'H_FL_AR_S17_RC Slab_150': {'NO': '1.1.1.1.1', 'Family Category': '', 'Building Tag': '', "Q'ty Cal Type Tag": 'FL-Q1', 'Standard Type': 'H_FL_AR_S17_RC Slab', 'Family Type Name': 'H_FL_AR_S17_RC Slab_150', 'Work Master Code /w Description': 'A04AS173-00001 Finishing Work Exterior/Interior Finish Work Steel Trowel Finish        ', 'Quantity': '', 'Remark(물량관련)': '', 'wmSpecs': [{'Work Master Code': 'A03AF032-00007', 'GaugeCode': '', 'Unit': 'M3', 'Work Category-L1': 'Concrete Work', 'Work Category-L2': 'Superstructure Work', 'Work Category-L3': 'Structural Concrete', 'Spec. 1- L4': 0.0, 'Spec. 2- L5': 'Cement Type-1', 'Spec. 3- L6': "25MPa < F'c (Cylinder Strength) ≤ 30MPa", 'Spec. 4- L7': 0.0, 'Spec. 5- L8': 0.0, 'Spec. 6- L9': '', 'Spec. 7- L10': 0.0, 'Spec. 8- L11': '', 'BOQ Spec1': 0.0, 'BOQ Spec2': '', 'BOQ Spec3': 0.0, 'BOQ Spec4': 0.0, 'BOQ Spec5': 0.0, 'BOQ Spec6': 0.0, 'BOQ Spec7': 0.0, 'BOQ Spec8': 0.0, 'BOQ Spec9': 0.0, 'Description': "ASTM C150 Type I or Type IA \nF'c (Cylinder Strength) = 28MPa", '입찰_물량산출식': '= V', '실행_물량산출식': '= V'}, {'Work Master Code': 'A03AF037-00003', 'GaugeCode': '', 'Unit': 'TON', 'Work Category-L1': 'Concrete Work', 'Work Category-L2': 'Superstructure Work', 'Work Category-L3': 'Rebar Work', 'Spec. 1- L4': 'Deformed Bar (Non-Coat.)', 'Spec. 2- L5': 0.0, 'Spec. 3- L6': '300MPa<Fy≤400MPa', 'Spec. 4- L7': 0.0, 'Spec. 5- L8': 0.0, 'Spec. 6- L9': '', 'Spec. 7- L10': 0.0, 'Spec. 8- L11': '', 'BOQ Spec1': 0.0, 'BOQ Spec2': '', 'BOQ Spec3': 0.0, 'BOQ Spec4': 0.0, 'BOQ Spec5': 0.0, 'BOQ Spec6': 0.0, 'BOQ Spec7': 0.0, 'BOQ Spec8': 0.0, 'BOQ Spec9': 0.0, 'Description': 'KS D3504 SD400 (Fy=400MPa)', '입찰_물량산출식': '= V*RE', '실행_물량산출식': '= V*RE'}, {'Work Master Code': 'A03AF036-00001', 'GaugeCode': '', 'Unit': 'M2', 'Work Category-L1': 'Concrete Work', 'Work Category-L2': 'Superstructure Work', 'Work Category-L3': 'Form Work (1 time in use)', 'Spec. 1- L4': 'Flat Form', 'Spec. 2- L5': 0.0, 'Spec. 3- L6': 0.0, 'Spec. 4- L7': 0.0, 'Spec. 5- L8': 0.0, 'Spec. 6- L9': 'Dressed Lumber, Plywood or Steel Form(Wood Planks are not Allowed) incl. Chamfer', 'Spec. 7- L10': 0.0, 'Spec. 8- L11': '', 'BOQ Spec1': 0.0, 'BOQ Spec2': '', 'BOQ Spec3': 0.0, 'BOQ Spec4': 0.0, 'BOQ Spec5': 0.0, 'BOQ Spec6': 0.0, 'BOQ Spec7': 0.0, 'BOQ Spec8': 0.0, 'BOQ Spec9': 0.0, 'Description': '', '입찰_물량산출식': '= A', '실행_물량산출식': '= A'}, {'Work Master Code': 'A04AS173-00001', 'GaugeCode': '', 'Unit': 'M2', 'Work Category-L1': 'Finishing Work', 'Work Category-L2': 'Exterior/Interior Finish Work', 'Work Category-L3': 'Steel Trowel Finish', 'Spec. 1- L4': 0.0, 'Spec. 2- L5': 0.0, 'Spec. 3- L6': 0.0, 'Spec. 4- L7': 0.0, 'Spec. 5- L8': 0.0, 'Spec. 6- L9': '', 'Spec. 7- L10': 0.0, 'Spec. 8- L11': '', 'BOQ Spec1': 0.0, 'BOQ Spec2': '', 'BOQ Spec3': 0.0, 'BOQ Spec4': 0.0, 'BOQ Spec5': 0.0, 'BOQ Spec6': 0.0, 'BOQ Spec7': 0.0, 'BOQ Spec8': 0.0, 'BOQ Spec9': 0.0, 'Description': '', '입찰_물량산출식': '= A', '실행_물량산출식': '= A'}]}}, {'H_FL_AR_S17_RC Slab_150': {'NO': '1.1.1.1.1', 'Family Category': '', 'Building Tag': '', "Q'ty Cal Type Tag": 'FL-Q1', 'Standard Type': 'H_FL_AR_S17_RC Slab', 'Family Type Name': 'H_FL_AR_S17_RC Slab_150', 'Work Master Code /w Description': 'A04AM080-00006 Finishing Work Painting Work Floor Painting Epoxy Paint       ', 'Quantity': '', 'Remark(물량관련)': '', 'wmSpecs': [{'Work Master Code': 'A03AF032-00007', 'GaugeCode': '', 'Unit': 'M3', 'Work Category-L1': 'Concrete Work', 'Work Category-L2': 'Superstructure Work', 'Work Category-L3': 'Structural Concrete', 'Spec. 1- L4': 0.0, 'Spec. 2- L5': 'Cement Type-1', 'Spec. 3- L6': "25MPa < F'c (Cylinder Strength) ≤ 30MPa", 'Spec. 4- L7': 0.0, 'Spec. 5- L8': 0.0, 'Spec. 6- L9': '', 'Spec. 7- L10': 0.0, 'Spec. 8- L11': '', 'BOQ Spec1': 0.0, 'BOQ Spec2': '', 'BOQ Spec3': 0.0, 'BOQ Spec4': 0.0, 'BOQ Spec5': 0.0, 'BOQ Spec6': 0.0, 'BOQ Spec7': 0.0, 'BOQ Spec8': 0.0, 'BOQ Spec9': 0.0, 'Description': "ASTM C150 Type I or Type IA \nF'c (Cylinder Strength) = 28MPa", '입찰_물량산출식': '= V', '실행_물량산출식': ' ...

# %%
importedDB[0]['H_FL_AR_S17_RC Slab_150']['NO']
# Out:
# '1.1.1.1.1'
