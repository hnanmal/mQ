# %%
import matplotlib.pyplot as plt
# Out:
# c:\Users\HEC\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\HEC\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\Users\HEC\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
area_usage = [
    "Communication | Vacation", 
    "Eating habits | Commuting", 
    "Culture of hurry | Company adaptation", 
    "Personal time and activities | prices",
    "Weather | Hinting - Noticing Culture",
    "Divided Country | Hospital/Medical",
    ]
values = [
28
,20
,28
,18
,13
,7
]

plt.pie(values, labels=area_usage, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1b2d8cd7c10>,
# ...
#  [Text(0.7884607600756525, 0.7670264857362649, 'Communication | Vacation'),
#   Text(-0.5500000148652439, 0.9526279355804298, 'Eating habits | Commuting'),
#   Text(-1.0584947927196733, -0.29931383827904806, 'Culture of hurry | Company adaptation'),
#   Text(-0.030309763961955172, -1.099582338075949, 'Personal time and activities | prices'),
#   Text(0.8092962888912362, -0.7450097427462764, 'Weather | Hinting - Noticing Culture'),
#   Text(1.0795966373385266, -0.21088172193754912, 'Divided Country | Hospital/Medical')],
#  [Text(0.4300695054958104, 0.4183780831288717, '24.6%'),
#   Text(-0.3000000081083148, 0.5196152375893253, '17.5%'),
#   Text(-0.5773607960289125, -0.16326209360675345, '24.6%'),
#   Text(-0.01653259852470282, -0.5997721844050631, '15.8%'),
#   Text(0.4414343393952197, -0.406368950588878, '11.4%'),
#   Text(0.5888708930937417, -0.11502639378411769, '6.1%')])
