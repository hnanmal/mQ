# %%
import os
import json

# %%
dir(os)
def get_HSD_framResultFile():
    cwd = os.getcwd()
    allfiles = list(os.listdir(cwd))
    res = list(filter(lambda x: "HSD_frame" in x, allfiles))
    return res[0]
hsdFile = get_HSD_framResultFile()

# %%
with open(hsdFile, 'r', encoding='utf-8') as f:
    res = f.read()

# %%
frameInfoDict = json.loads(res)
frameInfoDict["element"]
# Out:
# {'2000000': {'element_force': [-1580240799.691272,
#    119220595.83735459,
#    145996325481.63306,
#    1580240799.691272,
#    -119220595.83735459,
#    330886057867.7852],
#   'startnode': '1000000',
#   'endnode': '1000001',
#   'guid': '0kNHQToJX6ax5FH5eimT9I'},
#  '2000001': {'element_force': [-594534508.8316717,
#    97155489.62834918,
#    291430524211.1523,
#    594534508.8316717,
#    -97155489.62834918,
#    194346923930.59363],
#   'startnode': '1000001',
#   'endnode': '1000002',
#   'guid': '0kNHQToJX6ax5FH5eimT9k'},
#  '2000002': {'element_force': [-145377944.0594964,
#    64810376.4682987,
#    125978543743.83755,
#    145377944.0594964,
#    -64810376.4682987,
#    100857773895.20789],
#   'startnode': '1000002',
#   'endnode': '1000003',
#   'guid': '0kNHQToJX6ax5FH5eimT9w'},
#  '2000100': {'element_force': [-3317749493.251098,
#    -12521348.292470876,
#    -29258516243.718716,
#    3317749493.251098,
#    12521348.292470876,
#    -20826876926.1648],
# ...
